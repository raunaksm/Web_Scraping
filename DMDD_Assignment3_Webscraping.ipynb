# %% [markdown]
# # Author Raunak Singh Matharu

# %%
from bs4 import BeautifulSoup
import requests
import uuid
uuid.uuid4()
import pandas as pd

# %% [markdown]
# # Raunak Singh Matharu Webscrape Page 1

# %%
url = 'https://www.swiggy.com/city/mumbai/top-rated-collection'

# %%
page = requests.get(url).text

# %%
#print(page)

# %%
soup = BeautifulSoup(page,'lxml')

# %%
header = soup.find_all('div',class_='nA6kb')

# %%
type(header)
# Out:
# bs4.element.ResultSet

# %%
List_Rest_Name=[]
List_rating=[]
List_Avgcost=[]
List_Speciality=[]
List_Timetaken=[]

# %%
for i in header:
    List_Rest_Name.append(i.text)

# %%
len(List_Rest_Name)
# Out:
# 16

# %%
rating = soup.find_all('div',class_="_9uwBC wY0my")

# %%
for i in rating:
    List_rating.append(i.text)

# %%
len(List_rating)
# Out:
# 16

# %%
rating = soup.find_all('div',class_="_9uwBC _2lAlc")
for i in rating:
    List_rating.append(i.text)
len(List_rating)
# Out:
# 16

# %%
Avgcost = soup.find_all('div',class_="nVWSi")

# %%
for i in Avgcost:
    List_Avgcost.append(i.text)

# %%
len(List_Avgcost)
# Out:
# 16

# %%
Speciality = soup.find_all('div',class_="_1gURR")

# %%
for i in Speciality:
    List_Speciality.append(i.text)

# %%
len(List_Speciality)
# Out:
# 16

# %%
timetaken = soup.find_all('div',class_="_3Mn31")

# %%
for i in timetaken:
    List_Timetaken.append(i.text)

# %%
len(List_Timetaken)
# Out:
# 16

# %% [markdown]
# # Raunak Singh Matharu Webscrape Page 2

# %%
url = 'https://www.swiggy.com/city/mumbai/top-rated-collection?page=2'

# %%
page = requests.get(url).text

# %%
#print(page)

# %%
soup = BeautifulSoup(page,'lxml')

# %%
header = soup.find_all('div',class_='nA6kb')
for i in header:
   List_Rest_Name.append(i.text)
len(List_Rest_Name)
# Out:
# 32

# %%
rating = soup.find_all('div',class_="_9uwBC wY0my")
for i in rating:
    List_rating.append(i.text)
len(List_rating)
# Out:
# 32

# %%
rating = soup.find_all('div',class_="_9uwBC _2lAlc")
for i in rating:
    List_rating.append(i.text)
len(List_rating)
# Out:
# 32

# %%
Avgcost = soup.find_all('div',class_="nVWSi")
for i in Avgcost:
    List_Avgcost.append(i.text)
List_Avgcost
len(List_Avgcost)
# Out:
# 32

# %%
Speciality = soup.find_all('div',class_="_1gURR")
for i in Speciality:
    List_Speciality.append(i.text)
len(List_Speciality)
# Out:
# 32

# %%
timetaken = soup.find_all('div',class_="_3Mn31")
for i in timetaken:
    List_Timetaken.append(i.text)
len(List_Timetaken)
# Out:
# 32

# %% [markdown]
# 3rd website page to scrape

# %% [markdown]
# # Raunak Singh Matharu Webscrape Page 3

# %%
url = 'https://www.swiggy.com/city/mumbai/top-rated-collection?page=3'

# %%
page = requests.get(url).text

# %%
#print(page)

# %%
soup = BeautifulSoup(page,'lxml')

# %%
header = soup.find_all('div',class_='nA6kb')
for i in header:
    List_Rest_Name.append(i.text)
len(List_Rest_Name)
# Out:
# 48

# %%
rating = soup.find_all('div',class_="_9uwBC wY0my")
for i in rating:
    List_rating.append(i.text)
len(List_rating)
# Out:
# 48

# %%
rating = soup.find_all('div',class_="_9uwBC _2lAlc")
for i in rating:
    List_rating.append(i.text)
len(List_rating)
# Out:
# 48

# %%
Avgcost = soup.find_all('div',class_="nVWSi")
for i in Avgcost:
    List_Avgcost.append(i.text)
len(List_Avgcost)
# Out:
# 48

# %%
Speciality = soup.find_all('div',class_="_1gURR")
for i in Speciality:
    List_Speciality.append(i.text)
len(List_Speciality)
# Out:
# 48

# %%
timetaken = soup.find_all('div',class_="_3Mn31")
for i in timetaken:
    List_Timetaken.append(i.text)
len(List_Timetaken)
# Out:
# 48

# %% [markdown]
# # Raunak Singh Matharu Webscrape Page 4

# %%
url = 'https://www.swiggy.com/city/mumbai/top-rated-collection?page=4'
page = requests.get(url).text
print(page)
# Out:
# <!DOCTYPE html><html lang="en" class=><head>  <link rel="preconnect" href="https://res.cloudinary.com" crossorigin="anonymous">  <link rel="preconnect" href="https://analytics.swiggy.com" crossorigin="anonymous">   <link rel="dns-prefetch" href="https://res.cloudinary.com">  <link rel="dns-prefetch" href="https://analytics.swiggy.com">  <link rel="dns-prefetch" href="https://www.googletagmanager.com">  <link rel="dns-prefetch" href="https://www.gstatic.com">  <link rel="dns-prefetch" href="https://www.google-analytics.com">  <link rel="dns-prefetch" href="https://q.quora.com">  <link rel="dns-prefetch" href="https://www.google.co.in">  <link rel="dns-prefetch" href="https://www.facebook.com">  <link rel="dns-prefetch" href="https://www.googleadservices.com">  <link rel="dns-prefetch" href="https://bat.bing.com">  <meta http-equiv="Content-type" content="text/html; charset=utf-8"><meta charset="utf-8">  <link rel="stylesheet" href="https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/css/styles.157b0aa727cc7abb0e6b0bfe5f85241f.css" crossorigin="anonymous">   <link rel="preload" as="script" href="https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/js/manifest.3e88fa69c282905.js" crossorigin="anonymous">  <link rel="preload" as="script" href="https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/js/vendor.3e88fa69c282905.js" crossorigin="anonymous">  <link rel="preload" as="script" href="https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/js/app.3e88fa69c282905.js" crossorigin="anonymous">      <title>Top rated restaurants in Mumbai</title><meta name="description" content="Can&#39;t decide what to order? Here is the list of top rated restaurants in Mumbai"><meta name="keywords" content="top rated, best, number 1, popular, famous restaurants in Mumbai"><meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1">  <meta name="robots" content="index, follow">   <link rel="canonical" href="https://www.swiggy.com/mumbai/top-rated-collection?page=4">   <link rel="amphtml" href="https://www.swiggy.com/mumbai/top-rated-collection?page=4">    <meta name="og_site_name" property="og:site_name" content="Swiggy.com"><meta name="og_title" property="og:title" content="Top rated restaurants in Mumbai"><meta property="og:type" content="website"><meta property="og:description" content="Can&#39;t decide what to order? Here is the list of top rated restaurants in Mumbai">  <meta name="og_url" property="og:url" content="https://www.swiggy.com/city/mumbai/top-rated-collection">   <meta property="og:image" content="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto/TopRated_kyu7dk">  <link rel="icon" sizes="192x192" href="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_192,h_192/portal/c/logo_2022.png"><link rel="apple-touch-icon" sizes="192x192" href="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_192,h_192/portal/c/logo_2022.png"><meta name="msapplication-TileColor" content="#e46d47"><meta name="msapplication-TileImage" content="https://res.cloudinary.com/swiggy/image/upload/portal/c/mstile-150x150.png"><link rel="icon" type="image/x-icon" href="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_16,h_16/portal/c/logo_2022.ico"><link rel="shortcut icon" type="image/x-icon" href="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_32,h_32/portal/c/logo_2022.ico"><link rel="icon" type="image/png" href="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_96,h_96/portal/c/logo_2022.png"><link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://res.cloudinary.com/swiggy/image/upload/fl_lossy,f_auto,q_auto,w_72,h_72/portal/c/logo_2022.png"><script>"undefined"==typeof Promise&&document.write("<script src=\"https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/libs/es6-promise.js\" defer><\/script ...
#     sessionStorage.setItem("tid", "e8efa4cc-f7cd-475d-99ec-ca160b9b142f");   App.sid = "47f1ec65-f196-4205-a585-c34d97551791";   App.deviceId = "712fc95c-434d-7f1a-2292-df9d129de94c";   App.userId = 0;    App.__APP_DATA__ = {"collectionPageData":{"subCollections":[],"id":2,"createdAt":"2018-09-24T18:06:37.000Z","updatedAt":"2018-09-24T18:06:37.000Z","name":"Top Rated","title":"Top rated restaurants in {0}","slug":"top-rated","image":"TopRated_kyu7dk","description":"Can't decide what to order? Here is the list of top rated restaurants in {0}","keywords":"top rated, best, number 1, popular, famous restaurants in {0}","enabled":true,"filterQuery":"sortBy=RATING","serialNo":2,"info":null,"showCollection":false,"city":{"id":18,"name":"Mumbai","slug":"mumbai","latLng":"19.1197, 72.9051","cityId":5,"image":"swiggy_host_ytmrnn","info":"Order food & beverages online from restaurants near & around you. We deliver food from your neighborhood local joints, your favorite cafes, luxurious & elite restaurants in your area. Exciting bit? We place no minimum order restrictions! Order in as little (or as much) as you?d like. We?ll Swiggy it to you!","description":null,"keywords":null,"showCollection":true,"enabled":true,"title":null}},"collectionRestaurantData":{"pages":17,"pageIndex":3,"scrubber":0,"configs":{"ribbons":{"PREORDER":{"type":"PREORDER","text":"Preorder","textColor":"#ffffff","imageId":"sfefefefeegeg","topBackgroundColor":"#d53d4c","bottomBackgroundColor":"#af2330","priority":3},"EXCLUSIVE":{"type":"EXCLUSIVE","text":"Exclusive","textColor":"#ffffff","imageId":"sfefefefeegeg","topBackgroundColor":"#fa4a5b","bottomBackgroundColor":"#d12a3b","priority":2},"NEW":{"type":"NEW","text":"Newly Added","textColor":"#ffffff","imageId":"sfefefefeegeg","topBackgroundColor":"#d53d4c","bottomBackgroundColor":"#af2330","priority":4},"REPEAT":{"type":"REPEAT","text":"Repeat","textColor":"#ffffff","imageId":"sfefefefeegeg","topBackgroundColor":"#D53D4C","bottomBackgroundColor":"#B02331","priority":6},"CLOUD":{"type":"CLOUD","text":"Daily Menus","textColor":"#ffffff","imageId":"sfefefefeegeg","topBackgroundColor":"#fa4a5b","bottomBackgroundColor":"#d12a3b","priority":5},"PREMIUM":{"type":"PREMIUM","text":"Premium","textColor":"#ffffff","imageId":"sfefefefeegeg","topBackgroundColor":"#8a584b","bottomBackgroundColor":"#583229","priority":7},"PROMOTED":{"type":"PROMOTED","text":"Promoted","textColor":"#ffffff","imageId":"sfefefefeegeg","topBackgroundColor":"#3a3c41","bottomBackgroundColor":"#1e2023","priority":1}},"croutons":{"RAIN":{"type":"Crouton","bgColor":"#282C3F","icon":"surge_listing_piuzrv","textColor":"#ffffff","title":"Bad Weather","message":"${amount} extra levied on some restaurants"},"SERVICEABLE_WITH_BANNER_RAIN":{"type":"Crouton","bgColor":"#282C3F","icon":"rain_crouton_4x","textColor":"#ffffff","title":"Bad Weather","message":"Few restaurants unserviceable due to rains"},"RAIN_LOW":{"type":"Crouton","bgColor":"#282C3F","icon":"surge_listing_piuzrv","textColor":"#ffffff","title":"Bad Weather","message":"Your orders may be delayed by 5-10 mins"},"RAIN_HIGH":{"type":"Crouton","bgColor":"#282C3F","icon":"surge_listing_piuzrv","textColor":"#ffffff","title":"Bad Weather","message":"Your orders may be delayed by 5-10 mins"},"SPECIAL":{"type":"Crouton","bgColor":"#282C3F","icon":"surge_listing_piuzrv","textColor":"#ffffff","title":"High Demand","message":"Surge fee of Rs ${amount} may be applicable"}}},"cards":[{"cardType":"restaurant","layoutAlignmentType":"VERTICAL","data":{"type":"restaurant","data":{"type":"F","id":"372200","name":"New Lajawaab Seekh Corner","uuid":"d17d7cb9-a980-4515-b15d-3d75212457f8","city":"5","area":"Bhd Kurla Weight Bridge","totalRatingsString":"100+ ratings","cloudinaryImageId":"wtjwh915fnytypbywvcs","cuisines":["Indian"],"tags":[],"costForTwo":20000,"costForTwoString":"₹200 FOR TWO","deliveryTime":36,"minDeliveryTime":36,"maxDeliveryTime":36,"slaString":"36 MINS","lastMileTravel":6.099999904632568,"slugs":{"restau ...
#     window._SentryCaptureMessage !== undefined && window._SentryCaptureMessage('Failed to load source', source);
# };</script> <script>function _SentryCaptureMessage(msg, url, ln) {
#         if (window.Sentry) {
#             window.Sentry.withScope(scope => {
#                 scope.setExtra("source", url);
#                 window.Sentry.captureException(msg);
#             });
#         } else {
#             window._swgy_errors.push([msg, url, ln]);
#         }
#     }
#
#     (function(w) {
#         if (typeof Sentry == "undefined") {
#             w._swgy_errors = w._swgy_errors || [];
#             w.addEventListener("error", _SentryCaptureMessage, false);
#         }
#     })(window);
#
#     function loadJS(src, callback) {
#         var script = document.createElement("script"),
#             loaded;
#         script.src = src;
#         script.async = true;
#         if (callback) {
#             script.onreadystatechange = script.onload = function() {
#                 if (!loaded) {
#                     callback(window);
#                 }
#                 loaded = true;
#             };
#         }
#         document.getElementsByTagName("head")[0].appendChild(script);
#     }
#
#     loadJS("https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/libs/sentry.js", function(w) {
#         w.removeEventListener("error", _SentryCaptureMessage, false);
#         w.Sentry.init({
#             dsn: "https://376574dea44b4055b0f0321b554b2d9d@sentry.io/5168579",
#             release: "production_2.35.1",
#             environment: "production",
#             // hardcoded for now
#             whitelistUrls: [/swiggy\.com/, /.*cloudinary\.com.*/],
#             ignoreUrls: [
#                 // Facebook flakiness
#                 /graph\.facebook\.com/i,
#                 // Facebook blocked
#                 /connect\.facebook\.net\/en_US\/all\.js/i,
#                 // Chrome extensions
#                 /extensions\//i,
#                 /^chrome:\/\//i,
#             ],
#             ignoreErrors: [
#                 // Random plugins/extensions
#                 "top.GLOBALS",
#                 // See: http://blog.errorception.com/2012/03/tale-of-unfindable-js-error.html
#                 "originalCreateNotification",
#                 "canvas.contentDocument",
#                 "MyApp_RemoveAllHighlights",
#                 "atomicFindClose",
#                 // Facebook borked
#                 "fb_xd_fragment",
#                 // See http://stackoverflow.com/questions/4113268/how-to-stop-javascript-injection-from-vodafone-proxy
#                 "bmi_SafeAddOnload",
#                 "EBCallBackMessageReceived",
#                 "failed to fetch",
#                 // Happens sometimes
#                 /.*Bad Gateway.*/i,
#                 // Happens sometimes
#                 /.*Blocked a frame with origin.*/i,
#                 // Internet connectivity issue
#                 /.*failed to fetch.*/i,
#                 // Tracking page has this
#                 /.*hostname could not.*/i,
#                 /.*connect to the server.*/i,
#                 // Internet connectivity issue in loading chunks
#                 /.*Loading chunk.*failed.*/i,
#                 // Internet issue
#                 /.*Network request failed.*/i,
#                 // offline
#                 /.*offline.*/gi,
#                 // iOS error caused when webapp goes in background
#                 /.*abort.*/i,
#                 // API timeouts
#                 /.*timeout.*/i,
#                 /.*timed out.*/i,
#                 // Client lost network connection
#                 /.*connection.*lost.*/i,
#                 // Tracking cancelled fetch request errors
#                 /.*cancelled.*/i,
#             ],
#         });
#         w._swgy_errors = w._swgy_errors || [];
#         for (var i = 0; i < w._swgy_errors.length; i++) {
#             w.Sentry.withScope(scope => {
#                 scope.setExtra("source", w._swgy_errors[i][1]);
#                 scope.setExtra("line", w._swgy_errors[i][2]);
#                 w.Sentry.captureException(w._swgy_errors[i][0]);
#             });
#         }
#
#         w.addEventListener("unhandledrejection", function(e) {
#             w.Sentry.captureException(e.reason);
#         });
#
#         w.addEventListener("rejectionhandled", function(e) {
#             w.Sentry.captureException(e.reason);
#         });
#     });</script>  <script src="https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/js/manifest.3e88fa69c282905.js" defer="defer" crossorigin="anonymous"></script>  <script src="https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/js/vendor.3e88fa69c282905.js" defer="defer" crossorigin="anonymous"></script>  <script src="https://res.cloudinary.com/swiggy/raw/upload/static-assets/production_ci_dweb/js/app.3e88fa69c282905.js" defer="defer" crossorigin="anonymous"></script> <script>"serviceWorker"in navigator&&"getRegistrations"in navigator.serviceWorker&&navigator.serviceWorker.getRegistrations().then(function(r){for(var e=0;e<r.length;e++)r[e].unregister()})</script> <script>window.__sendNRCustomEvent=function(e){var t=JSON.stringify(e),n=new XMLHttpRequest;n.withCredentials=!0,n.open("POST","https://insights-collector.newrelic.com/v1/accounts/737486/events"),n.setRequestHeader("X-Insert-Key","CPDMQSXvjxGCdL_E02P9eZ-NJcEg-uGk"),n.setRequestHeader("Content-Type","application/json"),n.send(t)}</script> <script type="text/javascript">var clevertap={event:[],profile:[],region:"in1",account:[],onUserLogin:[],notifications:[],privacy:[]};clevertap.account.push({id:"W86-ZZK-WR6Z"}),clevertap.privacy.push({optOut:!1}),clevertap.privacy.push({useIP:!1}),function(){var t=document.createElement("script");t.type="text/javascript",t.async=!0,t.src=("https:"==document.location.protocol?"https://d2r1yp2w7bby2u.cloudfront.net":"http://static.clevertap.com")+"/js/a.js";var e=document.getElementsByTagName("script")[0];e.parentNode.insertBefore(t,e)}()</script></body></html>

# %%
soup = BeautifulSoup(page,'lxml')

# %%
header = soup.find_all('div',class_='nA6kb')
for i in header:
    List_Rest_Name.append(i.text)
len(List_Rest_Name)
# Out:
# 64

# %%
rating = soup.find_all('div',class_="_9uwBC wY0my")
for i in rating:
    List_rating.append(i.text)
len(List_rating)
# Out:
# 64

# %%
rating = soup.find_all('div',class_="_9uwBC _2lAlc")
for i in rating:
    List_rating.append(i.text)
len(List_rating)
# Out:
# 64

# %%
Avgcost = soup.find_all('div',class_="nVWSi")
for i in Avgcost:
    List_Avgcost.append(i.text)
len(List_Avgcost)
# Out:
# 64

# %%
Speciality = soup.find_all('div',class_="_1gURR")
for i in Speciality:
    List_Speciality.append(i.text)
len(List_Speciality)
# Out:
# 64

# %%
timetaken = soup.find_all('div',class_="_3Mn31")
for i in timetaken:
    List_Timetaken.append(i.text)
len(List_Timetaken)
# Out:
# 64

# %%
List_Timetaken
# Out:
# ['5.0•39 MINS•₹300 FOR TWO',
#  '4.9•47 MINS•₹300 FOR TWO',
#  '4.8•47 MINS•₹250 FOR TWO',
#  '4.8•55 MINS•₹250 FOR TWO',
#  '4.8•43 MINS•₹200 FOR TWO',
#  '4.8•28 MINS•₹500 FOR TWO',
#  '4.8•37 MINS•₹350 FOR TWO',
#  '4.7•58 MINS•₹250 FOR TWO',
#  '4.7•34 MINS•₹300 FOR TWO',
#  '4.6•41 MINS•₹600 FOR TWO',
#  '4.5•50 MINS•₹250 FOR TWO',
#  '4.5•56 MINS•₹250 FOR TWO',
#  '4.5•40 MINS•₹250 FOR TWO',
#  '4.5•38 MINS•₹300 FOR TWO',
#  '4.5•25 MINS•₹300 FOR TWO',
#  '4.4•48 MINS•₹1200 FOR TWO',
#  '4.4•46 MINS•₹200 FOR TWO',
#  '4.4•51 MINS•₹250 FOR TWO',
#  '4.4•45 MINS•₹300 FOR TWO',
#  '4.4•36 MINS•₹700 FOR TWO',
#  '4.4•32 MINS•₹200 FOR TWO',
#  '4.4•39 MINS•₹600 FOR TWO',
#  '4.4•27 MINS•₹350 FOR TWO',
#  '4.3•41 MINS•₹400 FOR TWO',
#  '4.3•47 MINS•₹1200 FOR TWO',
#  '4.3•41 MINS•₹600 FOR TWO',
#  '4.3•45 MINS•₹600 FOR TWO',
#  '4.3•41 MINS•₹150 FOR TWO',
#  '4.3•44 MINS•₹320 FOR TWO',
#  '4.3•39 MINS•₹150 FOR TWO',
#  '4.3•38 MINS•₹200 FOR TWO',
#  '4.3•34 MINS•₹300 FOR TWO',
#  '4.3•38 MINS•₹300 FOR TWO',
#  '4.3•46 MINS•₹350 FOR TWO',
#  '4.3•31 MINS•₹450 FOR TWO',
#  '4.3•29 MINS•₹600 FOR TWO',
#  '4.3•37 MINS•₹300 FOR TWO',
#  '4.3•25 MINS•₹250 FOR TWO',
#  '4.3•31 MINS•₹300 FOR TWO',
#  '4.3•29 MINS•₹150 FOR TWO',
#  '4.3•30 MINS•₹400 FOR TWO',
#  '4.3•29 MINS•₹700 FOR TWO',
#  '4.2•47 MINS•₹500 FOR TWO',
#  '4.2•53 MINS•₹250 FOR TWO',
#  '4.2•38 MINS•₹200 FOR TWO',
#  '4.2•36 MINS•₹200 FOR TWO',
#  '4.2•39 MINS•₹300 FOR TWO',
#  '4.2•34 MINS•₹400 FOR TWO',
#  '4.2•36 MINS•₹200 FOR TWO',
#  '4.2•38 MINS•₹250 FOR TWO',
#  '4.2•34 MINS•₹299 FOR TWO',
#  '4.2•31 MINS•₹250 FOR TWO',
#  '4.2•42 MINS•₹250 FOR TWO',
#  '4.2•30 MINS•₹600 FOR TWO',
#  '4.2•21 MINS•₹320 FOR TWO',
#  '4.1•35 MINS•₹500 FOR TWO',
#  '4.1•31 MINS•₹250 FOR TWO',
#  '4.1•38 MINS•₹450 FOR TWO',
#  '4.1•37 MINS•₹300 FOR TWO',
#  '4.1•40 MINS•₹300 FOR TWO',
#  '4.1•31 MINS•₹300 FOR TWO',
#  '4.1•35 MINS•₹200 FOR TWO',
#  '4.1•31 MINS•₹700 FOR TWO',
#  '4.0•55 MINS•₹350 FOR TWO']

# %%
# data cleaning only taking the 5 and 6 index of List_Timetaken to extract time taken
List_Timetaken1=[]
for i in range(len(List_Timetaken)):
    List_Timetaken1.append(List_Timetaken[i][4:6])
#List_Timetaken1.append
List_Timetaken1
# Out:
# ['39',
#  '47',
#  '47',
#  '55',
#  '43',
#  '28',
#  '37',
#  '58',
#  '34',
#  '41',
#  '50',
#  '56',
#  '40',
#  '38',
#  '25',
#  '48',
#  '46',
#  '51',
#  '45',
#  '36',
#  '32',
#  '39',
#  '27',
#  '41',
#  '47',
#  '41',
#  '45',
#  '41',
#  '44',
#  '39',
#  '38',
#  '34',
#  '38',
#  '46',
#  '31',
#  '29',
#  '37',
#  '25',
#  '31',
#  '29',
#  '30',
#  '29',
#  '47',
#  '53',
#  '38',
#  '36',
#  '39',
#  '34',
#  '36',
#  '38',
#  '34',
#  '31',
#  '42',
#  '30',
#  '21',
#  '35',
#  '31',
#  '38',
#  '37',
#  '40',
#  '31',
#  '35',
#  '31',
#  '55']

# %%
from uuid import uuid4
List_Order_id=[]
for i in List_Rest_Name:
    List_Order_id.append(str(uuid4()))

# %%
List_City=[]

# %%
for i in range (len(List_Timetaken1)):
    List_City.append('Mumbai')

# %%
List_Order_id
# Out:
# ['c45cd48d-01fc-47ae-9f13-5d3262802dca',
#  '6d1a5e0a-ca98-47b2-ac20-a26b18e92be8',
#  'a415a6f5-704b-4c3b-b25a-f05c984a6120',
#  '22654fd2-3d96-49d5-a2ce-66ead54cf252',
#  '4350b44d-6326-4005-a4ae-507012f1c93a',
#  '8ceb0fde-f152-4820-9dea-7a4952e5364d',
#  '9291ace8-41be-41aa-baf3-5da4b947cbe2',
#  '915dd036-e176-4103-8da5-1656632abbb6',
#  '4c67e2ac-1feb-4964-b974-15209d1fb639',
#  'b74895fe-5b76-4d75-ad96-010e2c5da7d9',
#  '1656d796-5de9-49b0-a413-fd4cb0cb7e48',
#  '05787e7b-ce43-4b5c-8d39-2ca83335a368',
#  'af8cf5e8-fba0-4cc6-b597-366d65311f7b',
#  '50c31c4d-8ba2-421c-863f-b4c9ddace781']

# %%
List_Timetaken1
# Out:
# ['39',
#  '47',
#  '47',
#  '55',
#  '43',
#  '28',
#  '37',
#  '58',
#  '34',
#  '41',
#  '50',
#  '56',
#  '40',
#  '38',
#  '25',
#  '48',
#  '46',
#  '51',
#  '45',
#  '36',
#  '32',
#  '39',
#  '27',
#  '41',
#  '47',
#  '41',
#  '45',
#  '41',
#  '44',
#  '39',
#  '38',
#  '34',
#  '38',
#  '46',
#  '31',
#  '29',
#  '37',
#  '25',
#  '31',
#  '29',
#  '30',
#  '29',
#  '47',
#  '53',
#  '38',
#  '36',
#  '39',
#  '34',
#  '36',
#  '38',
#  '34',
#  '31',
#  '42',
#  '30',
#  '21',
#  '35',
#  '31',
#  '38',
#  '37',
#  '40',
#  '31',
#  '35',
#  '31',
#  '55']

# %%
List_Speciality
# Out:
# ['Pizzas, Italian, Desserts, Beverages',
#  'Fast Food, Snacks, Beverages',
#  'Beverages',
#  'Pizzas, Beverages',
#  'Waffle, Desserts, Beverages',
#  'Desserts, Bakery',
#  'Asian, Chinese, Tibetan, Beverages',
#  'Continental, Pastas',
#  'Pizzas, Burgers, Cafe, Pastas',
#  'Chinese, North Indian, Snacks, Fast Food, Pizzas',
#  'Burgers',
#  'Fast Food',
#  'Ice Cream, Desserts',
#  'Desserts, Beverages, Bakery',
#  'Ice Cream, Healthy Food',
#  'Italian, Mexican, Asian',
#  'Beverages',
#  'Snacks, Fast Food, Beverages',
#  'Snacks, Beverages, Waffle, Desserts',
#  'Mughlai, Lebanese, Chinese, Salads',
#  'Waffle, Desserts, Ice Cream, Beverages',
#  'Pizzas, Fast Food, American, Italian, Beverages',
#  'Salads, Snacks, Desserts, Beverages',
#  'Salads, Fast Food',
#  'Italian, American, Desserts',
#  'American, Burgers',
#  'Italian, Pizzas',
#  'Chaat, Indian',
#  'Indian, Chinese, Biryani',
#  'Beverages, Juices, Pizzas',
#  'Desserts, Ice Cream, Beverages',
#  'Ice Cream, Beverages',
#  'North Indian, Mughlai, Desserts, Beverages',
#  'Snacks, Chinese, Combo, North Indian, Beverages, Biryani',
#  'Chinese, Indian, North Indian, Tandoor, Desserts, Fast Food',
#  'Burgers, Beverages, Cafe, Desserts',
#  'Pizzas, Italian',
#  'Bakery, Beverages, Chaat, Desserts, Home Food, Italian, Maharashtrian, Snacks, S...',
#  'American, Snacks, Beverages',
#  'Bakery, Beverages, Maharashtrian, Snacks, Street Food, South Indian, Punjabi',
#  'Burgers, Beverages, Cafe, Desserts',
#  'Mexican',
#  'Healthy Food, Beverages',
#  'North Indian',
#  'Indian',
#  'Indian, Snacks',
#  'Indian, Chinese, Thalis, Biryani, Seafood, Tandoor',
#  'Beverages, Desserts',
#  'Indian',
#  'Waffle, Beverages, Desserts, Bakery',
#  'North Indian, Indian, Beverages, Biryani',
#  'Chinese, Biryani, Indian, Tandoor, Mughlai, Malwani',
#  'Fast Food, Healthy Food',
#  'Burgers, Fast Food, American',
#  'Fast Food',
#  'Indian, Chinese, Tandoor',
#  'American, Mexican, Fast Food, Snacks, Beverages',
#  'Chinese, Thai',
#  'Indian, Desserts, Ice Cream, Bakery',
#  'Waffle, Desserts, Bakery, Beverages',
#  'Chinese, Tandoor, Indian, Biryani, Malwani, North Indian',
#  'Desserts, Ice Cream',
#  'Pizzas, Italian, Pastas, Beverages, Desserts',
#  'Pizzas']

# %%
List_Avgcost
# Out:
# ['₹300 FOR TWO',
#  '₹300 FOR TWO',
#  '₹250 FOR TWO',
#  '₹250 FOR TWO',
#  '₹200 FOR TWO',
#  '₹500 FOR TWO',
#  '₹350 FOR TWO',
#  '₹250 FOR TWO',
#  '₹300 FOR TWO',
#  '₹600 FOR TWO',
#  '₹250 FOR TWO',
#  '₹250 FOR TWO',
#  '₹250 FOR TWO',
#  '₹300 FOR TWO',
#  '₹300 FOR TWO',
#  '₹1200 FOR TWO',
#  '₹200 FOR TWO',
#  '₹250 FOR TWO',
#  '₹300 FOR TWO',
#  '₹700 FOR TWO',
#  '₹200 FOR TWO',
#  '₹600 FOR TWO',
#  '₹350 FOR TWO',
#  '₹400 FOR TWO',
#  '₹1200 FOR TWO',
#  '₹600 FOR TWO',
#  '₹600 FOR TWO',
#  '₹150 FOR TWO',
#  '₹320 FOR TWO',
#  '₹150 FOR TWO',
#  '₹200 FOR TWO',
#  '₹300 FOR TWO',
#  '₹300 FOR TWO',
#  '₹350 FOR TWO',
#  '₹450 FOR TWO',
#  '₹600 FOR TWO',
#  '₹300 FOR TWO',
#  '₹250 FOR TWO',
#  '₹300 FOR TWO',
#  '₹150 FOR TWO',
#  '₹400 FOR TWO',
#  '₹700 FOR TWO',
#  '₹500 FOR TWO',
#  '₹250 FOR TWO',
#  '₹200 FOR TWO',
#  '₹200 FOR TWO',
#  '₹300 FOR TWO',
#  '₹400 FOR TWO',
#  '₹200 FOR TWO',
#  '₹250 FOR TWO',
#  '₹299 FOR TWO',
#  '₹250 FOR TWO',
#  '₹250 FOR TWO',
#  '₹600 FOR TWO',
#  '₹320 FOR TWO',
#  '₹500 FOR TWO',
#  '₹250 FOR TWO',
#  '₹450 FOR TWO',
#  '₹300 FOR TWO',
#  '₹300 FOR TWO',
#  '₹300 FOR TWO',
#  '₹200 FOR TWO',
#  '₹700 FOR TWO',
#  '₹350 FOR TWO']

# %%
List_rating
# Out:
# ['5.0',
#  '4.9',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.7',
#  '4.7',
#  '4.6',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.4',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.2',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.1',
#  '4.0']

# %%
List_Rest_Name
# Out:
# ['Winners Pizza (Fresh Dough)',
#  'Ande Ka Fanda',
#  'The Milky Way',
#  'Bliss Cafe',
#  'Miami Waffles & Jawbreakers',
#  'Le15 Patisserie Powai',
#  'Prasuma Momo Kitchen',
#  'Hungry Turtle',
#  'ALCAZAR',
#  '24x7 PENINSULA DELIVERY KITCHEN',
#  'Burgery Palace',
#  'Sandwich Pe charcha',
#  'Tude Premium Ice Creams',
#  'THE WAFFLE JAR',
#  'NOTO - Healthy Ice Cream',
#  'Quesso Ristorante',
#  'Cafe Nagori',
#  'Yummy Business',
#  'SLIDERS',
#  'Hit & Run',
#  'The Belgian Waffle Co.',
#  'Flash Pizza',
#  'Subway',
#  'Nothing But Chicken',
#  'Le Cafe (Jewel of Chembur)',
#  'Louis Burger',
#  'SLYCE',
#  'SHREENATH JI PAV BHAJI CENTER',
#  'SERAI FAMILY SKYDINE',
#  'WELCOME FASTFOOD AND JUICE CENTER',
#  'Alice in Gelatoland',
#  'Ice cream Factory & Shahi Durbar',
#  'Quick Combos',
#  'the egg magic',
#  'NEW AIRPORT RESTAURANT',
#  "McDonald's Gourmet Burger Collection",
#  "Crusto's - Cheese Burst Pizza",
#  'Chaayos Chai+Snacks=Relax',
#  'RushHrs',
#  'Chai Point',
#  "McDonald's",
#  'Maiz Mexican Kitchen',
#  'Protein Chef Cafe',
#  'Curry Kingdom',
#  'Rolls Mania',
#  'Baba Seekh Paratha Corner',
#  'AL ZAIKA DHABA',
#  'Shakey Wakey',
#  'New Lajawaab Seekh Corner',
#  'New York Waffles & Dinges',
#  'Cafe Vikhroli',
#  'Sai Lazeez',
#  'Wraps and Rolls',
#  'Nino Burgers',
#  'The J',
#  'JANATA TAWA AND GRILL',
#  'Jumboking Indian Burger',
#  'RJ Spice',
#  'Best Belgian waffle',
#  'Wack Waffles & Brownies',
#  'Sai Restaurant',
#  'Huber & Holly',
#  "Francesco's Pizzeria",
#  'Akkad Bakkad Bombay Boo - AB3']

# %%
data ={'Order_ID':List_Order_id,'Restaurent':List_Rest_Name,'Speciality':List_Speciality,'Rating':List_rating,'Avgcost':List_Avgcost,'Timetaken':List_Timetaken1,'City':List_City}

# %%
df = pd.DataFrame(data)
df
# Out:
#                                 Order_ID                     Restaurent  \
# 0   c45cd48d-01fc-47ae-9f13-5d3262802dca    Winners Pizza (Fresh Dough)
# 1   6d1a5e0a-ca98-47b2-ac20-a26b18e92be8                  Ande Ka Fanda
# 2   a415a6f5-704b-4c3b-b25a-f05c984a6120                  The Milky Way
# 3   22654fd2-3d96-49d5-a2ce-66ead54cf252                     Bliss Cafe
# 4   4350b44d-6326-4005-a4ae-507012f1c93a    Miami Waffles & Jawbreakers
# ..                                   ...                            ...
# 59  0051b15d-23a6-4e2f-8ab1-334b83ed8650        Wack Waffles & Brownies
# 60  1656d796-5de9-49b0-a413-fd4cb0cb7e48                 Sai Restaurant
# 61  05787e7b-ce43-4b5c-8d39-2ca83335a368                  Huber & Holly
# 62  af8cf5e8-fba0-4cc6-b597-366d65311f7b           Francesco's Pizzeria
# 63  50c31c4d-8ba2-421c-863f-b4c9ddace781  Akkad Bakkad Bombay Boo - AB3
#
#                                            Speciality Rating       Avgcost  \
# 0                Pizzas, Italian, Desserts, Beverages    5.0  ₹300 FOR TWO
# 1                        Fast Food, Snacks, Beverages    4.9  ₹300 FOR TWO
# 2                                           Beverages    4.8  ₹250 FOR TWO
# 3                                   Pizzas, Beverages    4.8  ₹250 FOR TWO
# 4                         Waffle, Desserts, Beverages    4.8  ₹200 FOR TWO
# ..                                                ...    ...           ...
# 59                Waffle, Desserts, Bakery, Beverages    4.1  ₹300 FOR TWO
# 60  Chinese, Tandoor, Indian, Biryani, Malwani, No...    4.1  ₹300 FOR TWO
# 61                                Desserts, Ice Cream    4.1  ₹200 FOR TWO
# 62       Pizzas, Italian, Pastas, Beverages, Desserts    4.1  ₹700 FOR TWO
# 63                                             Pizzas    4.0  ₹350 FOR TWO
#
#    Timetaken    City
# 0         39  Mumbai
# 1         47  Mumbai
# 2         47  Mumbai
# 3         55  Mumbai
# 4         43  Mumbai
# ..       ...     ...
# 59        40  Mumbai
# 60        31  Mumbai
# 61        35  Mumbai
# 62        31  Mumbai
# 63        55  Mumbai
#
# [64 rows x 7 columns]

# %%
#used to clean special character like ₹ in dataframe column Avgcost
df['Avgcost'] = df['Avgcost'].str.replace('\W', '', regex=True)

# %%
df
#df["TimeTaken"].replace("57Mins", "Mins")
# Out:
#                                 Order_ID                     Restaurent  \
# 0   c45cd48d-01fc-47ae-9f13-5d3262802dca    Winners Pizza (Fresh Dough)
# 1   6d1a5e0a-ca98-47b2-ac20-a26b18e92be8                  Ande Ka Fanda
# 2   a415a6f5-704b-4c3b-b25a-f05c984a6120                  The Milky Way
# 3   22654fd2-3d96-49d5-a2ce-66ead54cf252                     Bliss Cafe
# 4   4350b44d-6326-4005-a4ae-507012f1c93a    Miami Waffles & Jawbreakers
# ..                                   ...                            ...
# 59  0051b15d-23a6-4e2f-8ab1-334b83ed8650        Wack Waffles & Brownies
# 60  1656d796-5de9-49b0-a413-fd4cb0cb7e48                 Sai Restaurant
# 61  05787e7b-ce43-4b5c-8d39-2ca83335a368                  Huber & Holly
# 62  af8cf5e8-fba0-4cc6-b597-366d65311f7b           Francesco's Pizzeria
# 63  50c31c4d-8ba2-421c-863f-b4c9ddace781  Akkad Bakkad Bombay Boo - AB3
#
#                                            Speciality Rating    Avgcost  \
# 0                Pizzas, Italian, Desserts, Beverages    5.0  300FORTWO
# 1                        Fast Food, Snacks, Beverages    4.9  300FORTWO
# 2                                           Beverages    4.8  250FORTWO
# 3                                   Pizzas, Beverages    4.8  250FORTWO
# 4                         Waffle, Desserts, Beverages    4.8  200FORTWO
# ..                                                ...    ...        ...
# 59                Waffle, Desserts, Bakery, Beverages    4.1  300FORTWO
# 60  Chinese, Tandoor, Indian, Biryani, Malwani, No...    4.1  300FORTWO
# 61                                Desserts, Ice Cream    4.1  200FORTWO
# 62       Pizzas, Italian, Pastas, Beverages, Desserts    4.1  700FORTWO
# 63                                             Pizzas    4.0  350FORTWO
#
#    Timetaken    City
# 0         39  Mumbai
# 1         47  Mumbai
# 2         47  Mumbai
# 3         55  Mumbai
# 4         43  Mumbai
# ..       ...     ...
# 59        40  Mumbai
# 60        31  Mumbai
# 61        35  Mumbai
# 62        31  Mumbai
# 63        55  Mumbai
#
# [64 rows x 7 columns]

# %%
#used to remove FORTWO letters in Avgcost Column in DataFrame
df = df.replace("FORTWO"," ",regex = True)

# %%
df
# Out:
#                                 Order_ID                     Restaurent  \
# 0   c45cd48d-01fc-47ae-9f13-5d3262802dca    Winners Pizza (Fresh Dough)
# 1   6d1a5e0a-ca98-47b2-ac20-a26b18e92be8                  Ande Ka Fanda
# 2   a415a6f5-704b-4c3b-b25a-f05c984a6120                  The Milky Way
# 3   22654fd2-3d96-49d5-a2ce-66ead54cf252                     Bliss Cafe
# 4   4350b44d-6326-4005-a4ae-507012f1c93a    Miami Waffles & Jawbreakers
# ..                                   ...                            ...
# 59  0051b15d-23a6-4e2f-8ab1-334b83ed8650        Wack Waffles & Brownies
# 60  1656d796-5de9-49b0-a413-fd4cb0cb7e48                 Sai Restaurant
# 61  05787e7b-ce43-4b5c-8d39-2ca83335a368                  Huber & Holly
# 62  af8cf5e8-fba0-4cc6-b597-366d65311f7b           Francesco's Pizzeria
# 63  50c31c4d-8ba2-421c-863f-b4c9ddace781  Akkad Bakkad Bombay Boo - AB3
#
#                                            Speciality Rating Avgcost  \
# 0                Pizzas, Italian, Desserts, Beverages    5.0    300
# 1                        Fast Food, Snacks, Beverages    4.9    300
# 2                                           Beverages    4.8    250
# 3                                   Pizzas, Beverages    4.8    250
# 4                         Waffle, Desserts, Beverages    4.8    200
# ..                                                ...    ...     ...
# 59                Waffle, Desserts, Bakery, Beverages    4.1    300
# 60  Chinese, Tandoor, Indian, Biryani, Malwani, No...    4.1    300
# 61                                Desserts, Ice Cream    4.1    200
# 62       Pizzas, Italian, Pastas, Beverages, Desserts    4.1    700
# 63                                             Pizzas    4.0    350
#
#    Timetaken    City
# 0         39  Mumbai
# 1         47  Mumbai
# 2         47  Mumbai
# 3         55  Mumbai
# 4         43  Mumbai
# ..       ...     ...
# 59        40  Mumbai
# 60        31  Mumbai
# 61        35  Mumbai
# 62        31  Mumbai
# 63        55  Mumbai
#
# [64 rows x 7 columns]

# %%
#delete empty rows 
new_df = df.dropna()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
new_df
# Out:
#                                 Order_ID  \
# 0   c45cd48d-01fc-47ae-9f13-5d3262802dca
# 1   6d1a5e0a-ca98-47b2-ac20-a26b18e92be8
# 2   a415a6f5-704b-4c3b-b25a-f05c984a6120
# 3   22654fd2-3d96-49d5-a2ce-66ead54cf252
# 4   4350b44d-6326-4005-a4ae-507012f1c93a
# 5   8ceb0fde-f152-4820-9dea-7a4952e5364d
# 6   9291ace8-41be-41aa-baf3-5da4b947cbe2
# 7   915dd036-e176-4103-8da5-1656632abbb6
# 8   4c67e2ac-1feb-4964-b974-15209d1fb639
# 9   b74895fe-5b76-4d75-ad96-010e2c5da7d9
# 10  98033a80-a589-404d-a2da-3cac60cf764b
# 11  0e348a97-1a63-45c5-9b60-acf3463ef367
# 62  af8cf5e8-fba0-4cc6-b597-366d65311f7b
# 63  50c31c4d-8ba2-421c-863f-b4c9ddace781
#
#                               Restaurent  \
# 0            Winners Pizza (Fresh Dough)
# 1                          Ande Ka Fanda
# 2                          The Milky Way
# 3                             Bliss Cafe
# 4            Miami Waffles & Jawbreakers
# 5                  Le15 Patisserie Powai
# 6                   Prasuma Momo Kitchen
# 7                          Hungry Turtle
# 8                                ALCAZAR
# 9        24x7 PENINSULA DELIVERY KITCHEN
# 10                        Burgery Palace
# 11                   Sandwich Pe charcha
# 12               Tude Premium Ice Creams
# 13                        THE WAFFLE JAR
# 14              NOTO - Healthy Ice Cream
# 15                     Quesso Ristorante
# 16                           Cafe Nagori
# 17                        Yummy Business
# 18                               SLIDERS
# 19                             Hit & Run
# 20                The Belgian Waffle Co.
# 21                           Flash Pizza
# 22                                Subway
# 23                   Nothing But Chicken
# 24            Le Cafe (Jewel of Chembur)
# 25                          Louis Burger
# 26                                 SLYCE
# 27         SHREENATH JI PAV BHAJI CENTER
# 28                  SERAI FAMILY SKYDINE
# 29     WELCOME FASTFOOD AND JUICE CENTER
# 30                   Alice in Gelatoland
# 31      Ice cream Factory & Shahi Durbar
# 32                          Quick Combos
# 33                         the egg magic
# 34                NEW AIRPORT RESTAURANT
# 35  McDonald's Gourmet Burger Collection
# 36         Crusto's - Cheese Burst Pizza
# 37             Chaayos Chai+Snacks=Relax
# 38                               RushHrs
# 39                            Chai Point
# 40                            McDonald's
# 41                  Maiz Mexican Kitchen
# 42                     Protein Chef Cafe
# 43                         Curry Kingdom
# 44                           Rolls Mania
# 45             Baba Seekh Paratha Corner
# 46                        AL ZAIKA DHABA
# 47                          Shakey Wakey
# 48             New Lajawaab Seekh Corner
# 49             New York Waffles & Dinges
# 50                         Cafe Vikhroli
# 51                            Sai Lazeez
# 52                       Wraps and Rolls
# 53                          Nino Burgers
# 54                                 The J
# 55                 JANATA TAWA AND GRILL
# 56               Jumboking Indian Burger
# 57                              RJ Spice
# 58                   Best Belgian waffle
# 59               Wack Waffles & Brownies
# 60                        Sai Restaurant
# 61                         Huber & Holly
# 62                  Francesco's Pizzeria
# 63         Akkad Bakkad Bombay Boo - AB3
#
#                                            Speciality Rating Avgcost  \
# 0                Pizzas, Italian, Desserts, Beverages    5.0    300
# 1                        Fast Food, Snacks, Beverages    4.9    300
# 2                                           Beverages    4.8    250
# 3                                   Pizzas, Beverages    4.8    250
# 4                         Waffle, Desserts, Beverages    4.8    200
# 5                                    Desserts, Bakery    4.8    500
# 6                  Asian, Chinese, Tibetan, Beverages    4.8    350
# 7                                 Continental, Pastas    4.7    250
# 8                       Pizzas, Burgers, Cafe, Pastas    4.7    300
# 9    Chinese, North Indian, Snacks, Fast Food, Pizzas    4.6    600
# 10                                            Burgers    4.5    250
# 11                                          Fast Food    4.5    250
# 12                                Ice Cream, Desserts    4.5    250
# 13                        Desserts, Beverages, Bakery    4.5    300
# 14                            Ice Cream, Healthy Food    4.5    300
# 15                            Italian, Mexican, Asian    4.4   1200
# 16                                          Beverages    4.4    200
# 22        27  Mumbai
# 23        41  Mumbai
# 24        47  Mumbai
# 25        41  Mumbai
# 26        45  Mumbai
# 27        41  Mumbai
# 28        44  Mumbai
# 29        39  Mumbai
# 30        38  Mumbai
# 31        34  Mumbai
# 32        38  Mumbai
# 33        46  Mumbai
# 34        31  Mumbai
# 35        29  Mumbai
# 36        37  Mumbai
# 37        25  Mumbai
# 38        31  Mumbai
# 39        29  Mumbai
# 40        30  Mumbai
# 41        29  Mumbai
# 42        47  Mumbai
# 43        53  Mumbai
# 44        38  Mumbai
# 45        36  Mumbai
# 46        39  Mumbai
# 47        34  Mumbai
# 48        36  Mumbai
# 49        38  Mumbai
# 50        34  Mumbai
# 51        31  Mumbai
# 52        42  Mumbai
# 53        30  Mumbai
# 54        21  Mumbai
# 55        35  Mumbai
# 56        31  Mumbai
# 57        38  Mumbai
# 58        37  Mumbai
# 59        40  Mumbai
# 60        31  Mumbai
# 61        35  Mumbai
# 62        31  Mumbai
# 63        55  Mumbai

# %%
#used to replace the blank space with not available 
df = df.replace("","Not Available ",regex = True)

# %%
df
# Out:
#                                 Order_ID  \
# 0   c45cd48d-01fc-47ae-9f13-5d3262802dca
# 1   6d1a5e0a-ca98-47b2-ac20-a26b18e92be8
# 2   a415a6f5-704b-4c3b-b25a-f05c984a6120
# 3   22654fd2-3d96-49d5-a2ce-66ead54cf252
# 4   4350b44d-6326-4005-a4ae-507012f1c93a
# 5   8ceb0fde-f152-4820-9dea-7a4952e5364d
# 6   9291ace8-41be-41aa-baf3-5da4b947cbe2
# 7   915dd036-e176-4103-8da5-1656632abbb6
# 8   4c67e2ac-1feb-4964-b974-15209d1fb639
# 9   b74895fe-5b76-4d75-ad96-010e2c5da7d9
# 10  98033a80-a589-404d-a2da-3cac60cf764b
# 11  0e348a97-1a63-45c5-9b60-acf3463ef367
# 12  71e30601-d528-4796-bdc7-64170c4024c7
# 13  a12639ce-f442-480e-a20a-b8bd8169893e
# 14  cd54c74e-2b46-444f-8ba6-5bae57bc16c4
# 15  f1900050-90b3-447e-a624-4471375cfd34
# 16  7af43db5-f782-46fe-992a-fb7555c64344
# 17  8fe07cbf-7026-41fe-af6f-6b274df8e010
# 18  dee7a02f-3f16-4edc-89d1-905da286b973
# 19  86a46cc1-1be5-441c-bb17-2f70157bc0b6
# 20  945c4081-520e-4823-b9d9-c1d37186281d
# 21  5580ce8f-2c10-4016-b78d-49310661fe1e
# 22  65940bd1-3358-46d2-a812-c0b87b167c5f
# 23  c28df036-cb86-4cf2-ace4-c407e02891b4
# 24  50461620-0d6f-470a-b0e2-cd8ee3d55518
# 25  dd2e6699-4fb0-41b9-b345-45cd22efc6de
# 26  e5bcd64d-624f-408c-8a48-3c8ff354bf7e
# 27  ef9db5da-c535-450b-bcdf-0f937c660c9e
# 28  2e80e5ce-07f0-4855-9e5c-a4bd5cfa9ff5
# 29  4b0f6d02-c466-4572-b2ae-cd7bf300ec33
# 30  bda512cf-d389-4943-bedb-814869af0a8d
# 31  9470351b-e7f4-4e63-813a-18f93267973c
# 39  Bakery, Beverages, Maharashtrian, Snacks, Stre...    4.3    150
# 40                 Burgers, Beverages, Cafe, Desserts    4.3    400
# 41                                            Mexican    4.3    700
# 42                            Healthy Food, Beverages    4.2    500
# 43                                       North Indian    4.2    250
# 44                                             Indian    4.2    200
# 45                                     Indian, Snacks    4.2    200
# 46  Indian, Chinese, Thalis, Biryani, Seafood, Tan...    4.2    300
# 47                                Beverages, Desserts    4.2    400
# 48                                             Indian    4.2    200
# 49                Waffle, Beverages, Desserts, Bakery    4.2    250
# 50           North Indian, Indian, Beverages, Biryani    4.2    299
# 51  Chinese, Biryani, Indian, Tandoor, Mughlai, Ma...    4.2    250
# 52                            Fast Food, Healthy Food    4.2    250
# 53                       Burgers, Fast Food, American    4.2    600
# 54                                          Fast Food    4.2    320
# 55                           Indian, Chinese, Tandoor    4.1    500
# 56    American, Mexican, Fast Food, Snacks, Beverages    4.1    250
# 57                                      Chinese, Thai    4.1    450
# 58                Indian, Desserts, Ice Cream, Bakery    4.1    300
# 59                Waffle, Desserts, Bakery, Beverages    4.1    300
# 60  Chinese, Tandoor, Indian, Biryani, Malwani, No...    4.1    300
# 61                                Desserts, Ice Cream    4.1    200
# 62       Pizzas, Italian, Pastas, Beverages, Desserts    4.1    700
# 63                                             Pizzas    4.0    350
#
#    Timetaken    City
# 0         39  Mumbai
# 1         47  Mumbai
# 2         47  Mumbai
# 3         55  Mumbai
# 4         43  Mumbai
# 5         28  Mumbai
# 6         37  Mumbai
# 7         58  Mumbai
# 8         34  Mumbai
# 9         41  Mumbai
# 10        50  Mumbai
# 11        56  Mumbai
# 12        40  Mumbai
# 13        38  Mumbai
# 14        25  Mumbai
# 15        48  Mumbai
# 16        46  Mumbai
# 17        51  Mumbai
# 18        45  Mumbai
# 19        36  Mumbai
# 20        32  Mumbai
# 21        39  Mumbai
# 22        27  Mumbai
# 23        41  Mumbai
# 24        47  Mumbai
# 25        41  Mumbai
# 26        45  Mumbai
# 27        41  Mumbai
# 28        44  Mumbai
# 29        39  Mumbai
# 30        38  Mumbai
# 31        34  Mumbai
# 32        38  Mumbai
# 33        46  Mumbai
# 34        31  Mumbai
# 35        29  Mumbai
# 36        37  Mumbai
# 37        25  Mumbai
# 38        31  Mumbai
# 39        29  Mumbai
# 40        30  Mumbai
# 41        29  Mumbai
# 42        47  Mumbai
# 43        53  Mumbai
# 44        38  Mumbai
# 45        36  Mumbai
# 46        39  Mumbai
# 47        34  Mumbai
# 48        36  Mumbai
# 49        38  Mumbai
# 50        34  Mumbai
# 51        31  Mumbai
# 52        42  Mumbai
# 53        30  Mumbai
# 54        21  Mumbai
# 55        35  Mumbai
# 56        31  Mumbai
# 57        38  Mumbai
# 58        37  Mumbai
# 59        40  Mumbai
# 60        31  Mumbai
# 61        35  Mumbai
# 62        31  Mumbai
# 63        55  Mumbai

# %%
#Fill Empty value
#df.fillna(130, inplace = True)

# %%
#print(df.duplicated())
#df.drop_duplicates(inplace = True)

# %%
#converting DataFrame to a csv file 
new_df.to_csv('./WebScrape_final.csv', index = False)
